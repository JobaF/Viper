# %%
import pandas as pd
dataset = pd.read_csv('OPENDATA_BOOKING_CALL_A_BIKE.csv', encoding='latin-1', sep=';')
frame = pd.DataFrame(dataset)

# %%
dataset.head()
# Out:
#    BOOKING_HAL_ID  CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# 0        21366843            51000          143517
# 1        21367069            51000          119830
# 2        21367072            51000          143501
# 3        21367118            51000          117519
# 4        21367155            51000          108641
#
#                             CUSTOMER_HAL_ID         DATE_BOOKING  \
# 0  A821059B555C7764A2FF801180874A2FCB326222  2014-01-01 00:34:54
# 1  1EBC930DB407ACEAE2FDE23A6CA40492EA3DFBB2  2014-01-01 01:39:55
# 2  7AD2C1B70137479062A6DD73815835986677BB2D  2014-01-01 01:40:20
# 3  A1062EF019B4E3E71C551572F1B284D55440E3C4  2014-01-01 01:56:00
# 4  4F4F752203EA6FC872D576E9289C4E1B362E16F6  2014-01-01 02:05:55
#
#              DATE_FROM           DATE_UNTIL COMPUTE_EXTRA_BOOKING_FEE  \
# 0  2014-01-01 00:34:54  2014-01-01 00:50:14                      Nein
# 1  2014-01-01 01:39:55  2014-01-01 01:57:27                      Nein
# ...

# %%
len(dataset)
# Out:
# 16228298

# %%
dataset_hamburg = dataset[dataset['CITY_RENTAL_ZONE'] == 'Hamburg']

# %%
dataset_hamburg = dataset[dataset['DATE_UNTIL'] < '2015-12-31 23:59:59']

# %%
final_dataset = pd.DataFrame(dataset_hamburg, columns=('BOOKING_HAL_ID','VEHICLE_HAL_ID', 'CUSTOMER_HAL_ID', 'DATE_BOOKING' , 'DATE_FROM', 'DATE_UNTIL', 'START_RENTAL_ZONE', 'START_RENTAL_ZONE_HAL_ID', 'END_RENTAL_ZONE', 'END_RENTAL_ZONE_HAL_ID', 'CITY_RENTAL_ZONE'))

# %%
len(final_dataset)
# Out:
# 8910030

# %%
final_dataset.to_csv('dataset_hamburg.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2c4bd01c0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2c4bd01c0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2c4bd01c0> returned a result with an error set
#
# ...

# %%
dataset_hamburg.tail()
# Out:
#          BOOKING_HAL_ID  CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# 8915076        34947552            51000          120006
# 8915078        34947784            51000          120511
# 8915155        34947289            50000          106690
# 8915156        34947434            50000          106690
# 8915157        34947473            51000          108021
#
#                                   CUSTOMER_HAL_ID         DATE_BOOKING  \
# 8915076  7D2B5BAC6ADEA583688FD63F585C03DA8DB4A28C  2015-12-31 22:40:18
# 8915078  1D4D3E67F4FF090A51233382B99BEEEEF697C20F  2015-12-31 23:37:41
# 8915155  1023887727C5758C36F8630A99475A5F98DB37CE  2015-12-31 21:05:42
# 8915156  1023887727C5758C36F8630A99475A5F98DB37CE  2015-12-31 21:50:10
# 8915157  6EE8FA6A6C25CEA3CA9B3144E6965349831E3BEA  2015-12-31 22:08:26
#
#                    DATE_FROM           DATE_UNTIL COMPUTE_EXTRA_BOOKING_FEE  \
# 8915076  2015-12-31 22:40:18  2015-12-31 22:48:34                      Nein
# ...

# %%
dataset.tail()
# Out:
#           BOOKING_HAL_ID  CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# 16228293        46385755            51000          119663
# 16228294        46385768            50000          165809
# 16228295        46385839            51000          120488
# 16228296        46386510            50000          116623
# 16228297        46386791            50000          110529
#
#                                    CUSTOMER_HAL_ID         DATE_BOOKING  \
# 16228293  1024F6970D5BE146588D64F6AF427E147ADC642E  2017-05-16 07:36:36
# 16228294  469EBC0DFB6D733E8C4AE1A7605B56170F7F636B  2017-05-16 07:37:07
# 16228295  CC6405146B51242A9169AB55E88A5C472EA1B2AA  2017-05-16 07:40:17
# 16228296  AE105561D195C422985C2B3BB1A790C187DA3A70  2017-05-16 08:02:12
# 16228297  DBB967CDDB3C6D5F0C7CC7A2FF2E8CC89B5ECE6E  2017-05-16 08:11:13
#
#                     DATE_FROM           DATE_UNTIL COMPUTE_EXTRA_BOOKING_FEE  \
# 16228293  2017-05-16 07:36:36  2017-05-16 07:44:16                        Ja
# ...

# %%
dataset.sort_values('DATE_UNTIL')
dataset.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-74bf88246329> in <module>
# ----> 1 dataset.sort_values('DATE_UNTIL')
#       2 dataset.tail()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5001
#    5002         new_data = self._data.take(
# -> 5003             indexer, axis=self._get_block_manager_axis(axis), verify=False
#    5004         )
#    5005
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1395         new_labels = self.axes[axis].take(indexer)
#    1396         return self.reindex_indexer(
# -> 1397             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1398         )
#    1399
#
# ...
